# %%
#Practice   Assignment Questions:


# # Write a Program to generate the Students Result . Accept the marks of five subjects from the user and display the result
# # according to following conditions

# # Percentage                         Division
# # >=75                          First Class with Distinction
# # >=60 and <75                     First Class
# # >=50 and <60                     Second Class
# # >=35 and <50                      Third Class
# # <35                               Fail

a=int(input("Enter your Maths mark: "))
b=int(input("Enter your Chemistry mark: "))
c=int(input("Enter your Physics mark: "))
d=int(input("Enter your Computer Science mark: "))
e=int(input("Enter your English mark: "))

max_mark=500

f=((a+b+c+d+e)/(max_mark))*100

if f >=75:
  print(f,"First class with Distinction")
elif f<75 and f>=60:
  print(f,"First class")
elif f<60 and f>=50:
  print(f,"Second Class")
elif f<50 and f>=35:
  print(f,"Third class")
else:
  print(f,"Fail")


# Write a program to perform the All the Arithmetic Operations of two numbers and
# nos you are accepting from user  and as well as Operator(Mini Calculator)

aa=int(input("Enter the 1st num: "))
bb=int(input("Enter the 2nd num: "))
cc=input("Which operation do you want to perform: sum,difference,product,division,quotient,remainder,power")

if cc=="sum":
  dd=a+b
  print("The sum of the nums is",dd)

elif cc=="difference":
  if aa > bb:
    dd = aa-bb
    print("The difference is", dd)
  else:
    dd= bb-aa
    print("The difference is",dd)
elif cc=="product":
  dd=aa*bb
  print("The product is",dd)

elif cc=='remainder':
  d=a%b
  print("The remainder is",dd)

elif cc=='division':
  dd=aa/bb
  print("The divison is",dd)
elif cc== 'power':
  dd=aa**bb
  print("The power is",dd)

else:
  dd=aa//bb
  print("The quotient is",dd)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-7a2a87838f3e> in <cell line: 14>()
#      12 # # <35                               Fail
#      13
# ---> 14 a=int(input("Enter your Maths mark: "))
#      15 b=int(input("Enter your Chemistry mark: "))
#      16 c=int(input("Enter your Physics mark: "))
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
# ...
