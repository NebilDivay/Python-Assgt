# %%
# Assignment Nos - 2(Operators):

#Question-1
# Program to find the Square root of a number
a = 16

b = a**0.5
print(b)

#Question-2
# Program to find the area of rectangle

c = int(input('Enter the length of the rectangle: '))
d = int(input('Enter the breadth of the rectangle: '))

e = c*d
print('The area of the rectangle is',e)


#Question-3
# Program to calculate the area  and Perimeter of the Square
f = int(input('Enter the length of the square: '))


print('The perimeter of the square is',4*f)
print('The area of the square is',f**2)


#Question-4
# program to Calculate Surface Volumne and Area of Cylinder

r = int(input('Enter the radius of the base of the cylinder: '))
h = int(input('Enter the height of the cylinder: '))

Surface_Volume = 3.14 * r**2 * h
print('The volume of the cylinder is',Surface_Volume,'cubic metre')

Surface_Area = 2 * 3.14 * r * h + 2 * 3.14 * r**2
print('The surface area of the cylinder is',Surface_Area, 'metre squre')

#Question-5
# Program to swap the values of Two Variables
i = 5
j = 10

k = j
j = i
i = k

print(i,j)
#Question-6
# Write Logical operators conditions with taking two variables

AB = False
CD = True

EF = AB and CD
GH = AB or CD

print(EF,GH)
