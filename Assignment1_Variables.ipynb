# %%
#Question-1
# Create five Numbers  Variables and Assign Some Values in it and display the Output of  that Variables
a=10
print(a, type(a))

b=20.3
print(b, type(b))

c=-20
print(c, type(c))

d=4+7j
print(d,type(d))

e=-20.3
print(e,type(e))

#Question-2
# Create Five String Variables and Assigns Some Values in it and display the Output of that Variables

aa='Alex'
print(aa)

bb="Alan"
print(bb)

cc='_'
print(cc)

dd='.'
print(dd)

ee='a,b!%$&*(+)'
print(ee)
#Question-3
# Store Days of the week  in One Variable

days = ('Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday')
print(days)


#Question-4
# Store at least 10  Floating point Number in one Variable

float_nums = (1.0,2.4,0.2,-4.5,-0.2,3.14,20/8,8.6,9.999,10.1)
print(float_nums)

#Question-5
# Create a Dictionary to store the data of Square of the Given Nos upto 10

square_nums = {1:1,2:4,3:9,4:16,5:25,6:36,7:49,8:64,9:81,10:100}
print(square_nums,type(square_nums))

#Question-6
# Create Five SET Variables and Assigns Some Values in it and display the Output of that Variables
aaa={1,2,3}
print(aaa)

bbb={4.5,-4.5}
print(bbb)

ccc={'lal',"Bibin"}
print(ccc)

ddd={'Mithun',3.14,5}
print(ddd)

eee={1,1,1,2,2,3,4,5,6,6,6,6,7}
print(eee)

#Question-8
# a = 72e3
# What is the meaning of a ?
# a is a variable and we are assigning value to the variable a. e3 means we are multiplying 72 by 10 to the power of 3.

#Question-9
# b = 72e-5
# What is the meaning of a ?

# b is a variable and we are assigning value to the variable b. e-5 means we are multiplying 72 by 10 to the power of -5.


#Question-10

# Create Five different data types of variables and Show the type of the variable:-

u = 1
print(u, type(u))

v = 1.02
print(v, type(v))

w = 'Mumbai'
print(w, type(w))

x = [1,2,2,3]
print(x, type(x))

y = 5 + 9j
print(y, type(y))

z = (1,2,3,4)
print(z, type(z))
# Out:
# 10 <class 'int'>
# 20.3 <class 'float'>
# -20 <class 'int'>
# (4+7j) <class 'complex'>
# -20.3 <class 'float'>
# Alex
# Alan
# _
# .
# a,b!%$&*(+)
# ('Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday')
# (1.0, 2.4, 0.2, -4.5, -0.2, 3.14, 2.5, 8.6, 9.999, 10.1)
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100} <class 'dict'>
# {1, 2, 3}
# {-4.5, 4.5}
# {'lal', 'Bibin'}
# {'Mithun', 3.14, 5}
# {1, 2, 3, 4, 5, 6, 7}
# 1 <class 'int'>
# 1.02 <class 'float'>
# Mumbai <class 'str'>
# [1, 2, 2, 3] <class 'list'>
# (5+9j) <class 'complex'>
# (1, 2, 3, 4) <class 'tuple'>
