# %%
#8) Program to print the following pattern

# *
# * *
# * * *
# * * * *


i=' * '
j=0
while j < 4:
  print(i)
  i= i + '* '
  j=j+1



#9) Program to print the table of 6 I want O/P as in given format
# 6 * 1 = 6
# 6 * 2 = 12
# 6 * 3 = 18
# .
# .
# .
# .
# 6 * 10 = 60



pp = 6
kk = 1
while kk < 11:
  gg = pp * kk
  print('{} * {} = {}'.format(pp,kk,gg))
  kk = kk + 1



#10) Program which accpets 5 integers values and print "DUPLICATES" if any of the values entered are repeated otherwise it prints
# "ALL UNIQUE" . Let 5 integers are (32 , 45 , 90 ,45 ,6 )
#  Now you can se dupliactes is 45 and uniques are 32 , 90 , 6 so my output should be in below format

# DUPLICATE : 45
# UNIQUE : 32
# UNIQUE : 90
# UNIQUE  : 6




aa = input("Enter 5 integers: ").split()

ab = set(aa)

for i in ab:
  c = aa.count(i)
  if c>1:
    print(f'DUPLICATE: {i}')
  else:
    print(f'UNIQUE: {i}')
# Out:
#  *
#  * *
#  * * *
#  * * * *
# 6 * 1 = 6
# 6 * 2 = 12
# 6 * 3 = 18
# 6 * 4 = 24
# 6 * 5 = 30
# 6 * 6 = 36
# 6 * 7 = 42
# 6 * 8 = 48
# 6 * 9 = 54
# 6 * 10 = 60
# Enter 5 integers: 12 50 34 67 67
# DUPLICATE: 67
# UNIQUE: 50
# UNIQUE: 12
# UNIQUE: 34
