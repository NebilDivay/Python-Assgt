# %%
# Asssignment on Functions
# ----------------------------------



# #Assignments:-

# Which keyword is use for function?

# A. define
# B. fun
# C. def
# D. function

Ans: C

# 2. Which of the following items are present in the function header?

# A. function name
# B. parameter list
# C. return value
# D. Both A and B

Ans: D

# 3. What is called when a function is defined inside a class?

# A. class
# B. function
# C. method
# D. module

Ans: C


# 4. If return statement is not used inside the function, the function will return:

# A. None
# B. 0
# C. Null
# D. Arbitary value

Ans: A

# 5. What is a recursive function?

# A. A function that calls other function.
# B. A function which calls itself.
# C. Both A and B
# D. None of the above

Ans: B

# 6. Which of the following is the use of id() function in python?

# A. Id() returns the size of object.
# B. Id() returns the identity of the object.
# C. Both A and B
# D. None of the above

Ans: B

# 7. Which of the following function headers is correct?

# A. def fun(a = 2, b = 3, c)
# B. def fun(a = 2, b, c = 3)
# C. def fun(a, b = 2, c = 3)
# D. def fun(a, b, c = 3, d)

Ans: C

# 8. In which part of memory does the system stores the parameter and local variables of funtion call?

# A. heap
# B. stack
# C. Uninitialized data segment
# D. None of the above

Ans: B

# 9. Which of the following will print the pi value defined in math module?

# A. print(pi)
# B. print(math.pi)
# C. from math import pi
# print(pi)
# D. from math import pi
# print(math.pi)

Ans: C

# 10.  Which operator is used in Python to import modules from packages?

# A. .
# B. *
# C. ->
# D. &

Ans: A

# 11. Where is function defined?

# A. Module
# B. class
# C. Another Function
# D. All of the above

Ans: D

# 12. Lambda is a function in python?

# A. True
# B. False
# C. Lambda is a function in python but user can not use it.
# D. None of the above

Ans: D

# 13. What is a variable defined outside a function referred to as?

# A. local variable
# B. global variable
# C. static Variable
# D. automatic variable

Ans: B

# 14. What is the output of the following program?

# z = lambda x : x * x

# print(z(6))
# A. 6
# B. 36
# C. 0
# D. error

Ans: B

# 15. What is the output of the following program?

# print(chr(ord(chr(97))))
# A. a
# B. A
# C. 97
# D. error

Ans: A

# 16. How is a function declared in Python?

# A. def function function_name():
# B. declare function function_name():
# C. def function_name():
# D. declare function_name():

Ans: C

# 17. Which one of the following is the correct way of calling a function?

# A. function_name()
# B. call function_name()
# C. ret function_name()
# D. function function_name()

Ans: A

# 18. Choose the correct option with reference to below Python code?

# def fn(a):

# 	print(a)

# x=90

# fn(x)

# A. x is the formal argument.
# B. a is the actual argument.
# C. fn(x) is the function signature.
# D. x is the actual argument.

Ans: D


# 19. Which one of the following is incorrect?

# A. The variables used inside function are called local variables.
# B. The local variables of a particular function can be used inside other functions, but these cannot be used in global space
# C. The variables used outside function are called global variables
# D. In order to change the value of global variable inside function, keyword global is used.

Ans: B

# 20. You can also create your own functions, these functions are called?

# A. built-in functions
# B. user-defined functions
# C. py function
# D. None of the above

Ans: B


# 21. Function blocks begin with the keyword?

# A. define
# B. fun
# C. function
# D. def

Ans: D

# 22. The code block within every function starts with a ?

# A. ;
# B. ::
# C. :
# D. %

Ans: C

# 23. A return statement with _____ arguments.

# A. No
# B. 1
# C. 2
# D. Any

Ans: D

# 24. ___________ are the arguments passed to a function in correct positional order.

# A. Required arguments
# B. Keyword arguments
# C. Default arguments
# D. Variable-length arguments

Ans: A

# 1. In Python, how are arguments passed?

# A. pass by value
# B. pass by reference
# C. It gives options to user to choose
# D. Both A and B

Ans: B

# 2. Which of the following is incorrect way of using an argument while defining a function in Python, where var1 and var2 are two arguments?

# A. def fn(var1, var2)
# B. def fn(var1, var2=5)
# C. def fn(*var1, var2)
# D. def fn(var1,*var2)

Ans: C

# 3. Which of the following is not a type of argument in Python?

# A. Keyword
# B. Variable argument count
# C. Positional
# D. None of these

Ans: D

# 4. Which of the following is the property of variable argument count?

# A. More than one argument can be used while calling the function.
# B. It should be always last while declaring the arguments.
# C. Both A and B
# D. None of these

Ans: B

# 5. Which of the following would result in an error?

# A. def function1(var1=2, var2):
#     var3=var1+var2
#      return var3
#     function1(3)

# B. def function1(var1, var2):
#     var3=var1+var2
#     return var3
#     function1(var1=2,var2=3)

# C. def function1(var1, var2):
#     var3=var1+var2
#     return var3
#     function1(var2=2,var1=3)

# D. def function1(var1, var2=5):
#     var3=var1+var2
#     return var3
#     function1(2,3)



Ans: A

# 6. What will be the output of the following Python code?

# def function1(var1=5, var2=7):
#     var2=9
#     var1=3
#     print (var1, " ", var2)
# function1(10,12)
# A. 5 7
# B. 3 9
# C. 10 12
# D. Error

Ans: B

# 7. What will be the output of the following Python code?

# def function1(var1,var2=5):
#     var1=2
#     var3=var1*var2
#     return var3
# var1=3
# print(function1(var1,var2))
# A. 10
# B. 15
# C. Error as var2 is not defined while calling the function
# D. Does not give any error as var2 is a default argument

Ans: C

# 8. . Which among the following are mutable objects in Python?
# (i) List
# (ii) Integer
# (iii) String
# (iv) Tuple


# A. i only
# B. i and ii only
# C. iii and iv only
# D. iv only

Ans: A

# 9. What will be the output of the following Python code?

# def function1(var1):
#     var1=var1+10
#     print (var1)
# var1=12
# function1(var1)
# print(var1)
# A. 22
#      22
# B. 12
#      12
# C. 22
#      22
# D. 12
#      22

Ans: 22
     12

# 10. What will be the output of the following Python code?

# def fn(var1):
#     var1.pop(1)
# var1=[1,2,3]
# fn(var1)
# print(var1)

# A. [1,2,3]
# B. [1,3]
# C. [2,3]
# D. [1,2]

Ans: B

# %%
# Assignment Coding Questions on Functions:
# -------------------------------------------------



# 1. Write a Python function that takes two numbers as input and returns their sum.

def sum(a, b):
  c = a + b
  return c

sum(2,3)

# 2. Write a Python function that takes a list of numbers as input and returns the maximum value in the list.

def lis(liss):
  d = max(liss)
  return d


lis([1,2,3,4,5])

# 3. Write a Python function that takes a string as input and returns the length of the string.

def stt(strng):
  f = len(strng)
  return f

stt('Longer')


# 4. Write a Python function that takes a list of strings as input and returns the longest string in the list.

def strn(lsst):
  l = lsst[0]
  m = len(lsst)
  for i in range(0,m):

    for j in range(i+1,m):

        if len(lsst[j]) > len(l):
          l = lsst[j]


  return l



Lisst =['Heavenlifiedying','And','From','Through','Alligatorred']
strn(Lisst)

# 5. Write a Python function that takes a dictionary as input and returns the number of key-value pairs in the dictionary.

def dic(dicti):
  hh = len(dicti)
  return hh

d1 = {"Name" :"CoachX", "Address" :"Delhi", "Pincode" :411025,}

dic(d1)

# 6. Write a Python function that takes a list of dictionaries as input and returns the total number of key-value pairs in all the dictionaries.
def dictio(di):
  hj = 0
  for i in di:

    hj += len(i)
  return hj

d2 = [{

      "University" :"SPPU",
      "Address" : "Pune",
      "Pincode" : 411046,
      "Department" : "Computer Science"},

      {
      "Subject" : "Python",
      "Practicals" :"CS-Labs",
      "Activities" :"Coding Comptetion"},
      {
                  "Business Administration":"Organizations Behavior",

                      "Practicals":"BA-Labs",
                      "Activities" :"Interview"
                  }

]

dictio(d2)
# 7. Write a Python function that takes a string as input and returns a new string with all the vowels removed.

def stnggg(st):
  ll = ('a','e','i','o','u')
  mm = ''
  for i in st:
    if i not in ll:
      mm += i
  return mm
jkk = 'Lamb'
stnggg(jkk)

# 8. Write a Python function that takes a list of strings as input and returns a new list with all the vowels removed from each string.
def stn(stt):
  oo =[]
  for i in stt:
    ll = ('a','e','i','o','u')
    nn = ''
    for j in i:
      if j not in ll:
        nn += j
    oo.append(nn)
  return oo

gg = ['asd','jkhlo','aeijhj']

stn(gg)


# 9. Write a Python function that takes a dictionary as input and returns a new dictionary with all the values doubled.

def aaa(dy):
  for key, val in dy.items():
    dy[key] = val * 2
  return dy


ff = {1:1, 2:4,3:9}
aaa(ff)


# 10. Write a Python function that takes a list of dictionaries as input and returns a new list with all the values doubled in each dictionary.

def bbb(dyy):
  jkk = []
  for i in dyy:
    for key,val in i.items():
      i[key] = val*2
    jkk.append(i)
  return jkk

fff = [{1:1, 2:4,3:9}, {4:16},{5:25,6:36}]

bbb(fff)
# Out:
# [{1: 2, 2: 8, 3: 18}, {4: 32}, {5: 50, 6: 72}]
