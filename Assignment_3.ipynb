# %%
#Assignments Questions:
#  1)Print the following pattern:-
# O/P:-
# *
# * *
# * * *
# * * * *
# * * * * *

# Ans:
# for i in range(0,5):
#   for j in range(0,i+1):
#     print('* ',end='')
#   print()


# 2)Print the following pattern:-
# O/P:-
# * * * * *
# * * * *
# * * *
# * *
# *

# Ans:
# for m in range(5,0,-1):
#   for n in range(m+1,1,-1):
#     print('* ',end='')
#   print()


#Answers below Question without running the programs:---

# 1. Which of the following is not used as loop in Python?

# A. for loop
# B. while loop
# C. do-while loop
# D. None of the above

# Ans: C

# 2. Which of the following is False regarding loops in Python?

# A. Loops are used to perform certain tasks repeatedly.
# B. While loop is used when multiple statements are to executed repeatedly until the given condition becomes False
# C. While loop is used when multiple statements are to executed repeatedly until the given condition becomes True.
# D. for loop can be used to iterate through the elements of lists.

# Ans: B

# 3. Which of the following is True regarding loops in Python?

# A. Loops should be ended with keyword "end".
# B. No loop can be used to iterate through the elements of strings.
# C. Keyword "break" can be used to bring control out of the current loop.
# D. Keyword "continue" is used to continue with the remaining statements inside the loop.

# Ans: C & D

# 4. What will be the output of given Python code?

# n=7

# c=0

# while(n):

#     if(n>5):

#         c=c+n-1

#         n=n-1

#     else:

#         break

# print(n)

# print(c)


# A. 5 11
# B. 5 9
# C. 7 11
# D. 5 2

# Ans: A

# 5. What will be the output of given Python code?

# str1="hello"
# c=0
# for x in str1:
#    if(x!="l"):
#        c=c+1
#    else:
#        pass
# print(c)
# A. 2
# B. 0
# C. 4
# D. 3

# Ans: D

# 6. Which of the following Python code will give different output from the others?

# A. for i in range(0,5):
#     print(i)
# B. for j in [0,1,2,3,4]:
#     print(j)
# C. for k in [0,1,2,3,4,5]:
#     print(k)
# D. for l in range(0,5,1):
#     print(l)

# Ans: C

# 7. How many times will the loop run?

# i=2

# while(i>0):

#     i=i-1

# A. 2
# B. 3
# C. 1
# D. 0

# Ans: A

# 8. What will be the output of the following Python code?

# list1 = [3 , 2 , 5 , 6 , 0 , 7, 9]

# sum = 0

# sum1 = 0

# for elem in list1:

#     if (elem % 2 == 0):

#         sum = sum + elem

#         continue

#     if (elem % 3 == 0):

#         sum1 = sum1 + elem



# print(sum , end=" ")

# print(sum1)

# A. 8 9
# B. 8 3
# C. 2 3
# D. 8 12

# Ans: D

# 9. What will be the output of the following Python code?

# for i in range(0,2,-1):

#     print("Hello")

# A. Hello
# B. Hello Hello
# C. No Output
# D. Error

# Ans: C


# 10)Which of the following is not a valid for loop in Python?

# A. for i in range(5):
# B. for i in range(0,5):
# C. for i in range(0,5,1):
# D. for i in range(5,0,-1):

# Ans: All are Valid Loop

# 11)What will be the output of the following code?

# x = "abcdef"

# for i in range(len(x)):

#     print(i)

# A. abcd
# B. 0 1 2 3
# C. 1 2 3 4
# D. a b c d

# Ans: The output will be 0 1 2 3 4 5

# 12. What keyword would you use to add an alternative condition to an if statement?

# A. else if
# B. elseif
# C. elif
# D. None of the above

# Ans: C

# 13. Can we write if/else into one line in python?

# A. Yes
# B. No
# C. if/else not used in python
# D. None of the above

# Ans: A

# 14. In a Python program, a control structure:

# A. Defines program-specific data structures
# B. Directs the order of execution of the statements in the program
# C. Dictates what happens before the program starts and after it terminates
# D. None of the above

# Ans: B

# 15. What will be output of this expression:

# 'p' + 'q' if '12'.isdigit() else 'r' + 's'
# A. pq
# B. rs
# C. pqrs
# D. pq12

# Ans: A

# 16. Which statement will check if a is equal to b?

# A. if a = b:
# B. if a == b:
# C. if a === c:
# D. if a == b

# Ans: B

# 17. Does python have switch case statement?

# A. True
# B. False
# C. Python has switch statement but we can not use it.
# D. None of the above

# Ans: B

# 18. Which of the following is a valid for loop in Python?

# A. for(i=0; i < n; i++)
# B. for i in range(0,5):
# C. for i in range(0,5)
# D. for i in range(5)

# Ans: B

# 19. Which of the following sequences would be generated bt the given line of code?

# range (5, 0, -2)
# A. 5 4 3 2 1 0 -1
# B. 5 4 3 2 1 0
# C. 5 3 1
# D. None of the above

# Ans: C

# 20. A while loop in Python is used for what type of iteration?

# A. indefinite
# B. discriminant
# C. definite
# D. indeterminate

# Ans: A

# 21. When does the else statement written after loop executes?

# A. When break statement is executed in the loop
# B. When loop condition becomes false
# C. Else statement is always executed
# D. None of the above

# Ans: B

# 22. What will be the output of the following code?

# x = "abcdef"

# i = "i"

# while i in x:

#     print(i, end=" ")
# A. a b c d e f
# B. abcdef
# C. i i i i i.....
# D. No Output

# Ans: D

# 23. What will be the output of the following code?

# x = "abcd"

# for i in range(len(x)):

#     print(i)
# A. abcd
# B. 0 1 2 3
# C. 1 2 3 4
# D. a b c d

# Ans: B

# 24. What will be the output of the following code?

# x = 12

# for i in x:

#     print(i)

# A. 12
# B. 1 2
# C. Error
# D. None of the above

# Ans: C

# 25. A loop becomes infinite loop if a condition never becomes ________.

# A. TRUE
# B. FALSE
# C. Null
# D. Both A and C

# Ans: B

# 26. If the else statement is used with a while loop, the else statement is executed when the condition becomes _______.

# A. TRUE
# B. FALSE
# C. Infinite
# D. Null

# Ans: B

# 27. Python programming language allows to use one loop inside another loop known as?

# A. switch
# B. foreach
# C. nested
# D. forall

# Ans: C

# 28. The ________ statement is a null operation.

# A. break
# B. exit
# C. return
# D. pass

# Ans: D

# 29. The continue statement can be used in?

# A. while loop
# B. for loop
# C. do-while
# D. Both A and B

# Ans: D


# 30)What will be the output of the following code?

# x = 12

# for i in x:

#     print(i)

# (A) 12
# (B) 1 2
# (C) Error
# (D) None of the above


# Ans: C
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *
# 3

# %%
# **For Loop:**

# 1. Write a program to print numbers from 1 to 10 using a for loop.

for i in range(1,11):
  print(i)

# 2. Write a program to print the sum of all numbers from 1 to 100 using a for loop.

sum = 0
for i in range(1,101):
  sum += i
print(sum)


# 3. Write a program to print the factorial of a number using a for loop.

a = int(input("Enter the number you want factorial of: "))

fact = 1
for i in range(1,a+1):
  fact*=i
print(f"The factorial of {a} is {fact}")

# 4. Write a program to print the Fibonacci sequence up to a certain number of terms using a for loop.
m = int(input("Get fibonocci series upto: "))
x = 0
y = 1
print(x)
print(y)

z = 0

for i in range(2,m):
  z = x + y
  x = y
  y = z
  print(z)



# 5. Write a program to print the multiplication table of a number using a for loop.

mult = int(input("Enter the number whose table you want: "))
max = int(input("Enter till which number you want the table: "))
print(f"The table of {mult} till {max} is:")
for i in range(1,max+1):
  table = i * mult
  print(f"{mult} * {i} = {table}")
  i += 1



# 6. Write a program to find the greatest common divisor (GCD) of two numbers using a for loop.

First = int(input("Enter the first num: "))
Second = int(input("Enter the second num: "))
GCD1 = 1
GCD2 = 1
for i in range(1,First):
  if First%i==0 and Second%i==0:
    GCD1 = i
for j in range(1,Second):
  if Second%j==0 and First%j==0:
    GCD2 = j
if GCD1%GCD2==0:
  print(f"The greatest common divisor of {First} and {Second} is {GCD1} ")
else:
  print(f"The greatest common divisor of {First} and {Second} is {GCD2} ")

# 7. Write a program to find the least common multiple (LCM) of two numbers using a for loop.
first = int(input("Enter the first num: "))
second = int(input("Enter the second num: "))
d = first * second
if first > second:
  for i in range(first,d+1):
    if i%first==0 and i%second==0:
      LCM = i
      break
  print(f"The least commom multiple of {first} and {second} is {LCM}")

else:
  for j in range(second,d+1):
    if j%first==0 and j%second==0:
      LCM = j
      break
  print(f"The least commom multiple of {first} and {second} is {LCM}")

# 8. Write a program to check if a number is prime or not using a for loop.

prime = int(input("Enter a number to check if its prime: "))

for i in range (2,prime):
  if prime%i==0:
    print(f"The number {prime} is not prime")
    break
  else:
    print(f"The number {prime} is prime")
    break




# 9. Write a program to find all the factors of a number using a for loop.

factor = int(input("Enter a number: "))
print(f"The factors of {factor} are: ")
for i in range (1,factor+1):
  if factor%i==0:
    print(i)


# 10. Write a program to print the pattern of a right triangle using a for loop.

nn = 5

for i in range(1,nn+1):
  print(i * "* ")







# **While Loop:**



# Implement all above Questions using While Loops

# 1. Write a program to print numbers from 1 to 10
i = 1
while i <= 10:
  print(i)
  i += 1


# 2. Write a program to print the sum of all numbers from 1 to 100
n = 1
sum = 0
while n <=100:
  sum += n
  n += 1
print(sum)


# 3. Write a program to print the factorial of a number

a = int(input("Enter the number you want factorial of: "))

fact = 1
print(f"The factorial of {a} is: ")
while a>1:
  fact*=a
  a-=1
print(fact)

# 4. Write a program to print the Fibonacci sequence up to a certain number of terms.
m = int(input("Get fibonocci series upto: "))
x = 0
y = 1
print(x)
print(y)

z = 0
jj=0
while jj < m -2 :
  z = x + y
  x = y
  y = z
  print(z)
  jj += 1



# 5. Write a program to print the multiplication table of a number.

multi = int(input("Enter the num whose table you want "))
maxi = int(input("Enter till which number you want the table "))
k = 1
while k <= maxi:
  tbl = multi * k
  print('{} * {} = {}'.format(multi,k,tbl))
  k = k + 1



# 6. Write a program to find the greatest common divisor (GCD) of two numbers.

Frst = int(input("Enter the first num: "))
Scnd = int(input("Enter the second num: "))
xx = min(Frst,Scnd)
divisor = 1
while xx>0:
  if Frst%xx == 0 and Scnd%xx == 0:
    divisor = xx
    break
  xx = xx - 1

print(f"The greatest common divisor of {Frst} and {Scnd} is {divisor} ")



# 7. Write a program to find the least common multiple (LCM) of two numbers
first = int(input("Enter the first num: "))
second = int(input("Enter the second num: "))

ef = max(first,second)

while True:
  if ef%first==0 and ef%second==0:
    LCM=ef
    break
  ef-=1

print(f"The least commom multiple of {first} and {second} is {LCM}")



# 8. Write a program to check if a number is prime or not.

prime = int(input("Enter a number to check if its prime: "))
xo=2
while xo<prime-1:
  if prime%xo==0:
    print(f"The number {prime} is not prime")
    break
  xo+=1
else:
    print(f"The number {prime} is prime")




# 9. Write a program to find all the factors of a number using a for loop.

factor = int(input("Enter a number: "))
print(f"The factors of {factor} are: ")
jk = 1
while jk<=factor:
  if factor%jk==0:
    print(jk)

  jk+=1

# 10. Write a program to print the pattern of a right triangle using a for loop.

ij=' * '
jkk=0
while jkk < 4:
  print(ij)
  ij= ij + '* '
  jkk=jkk+1
# Out:
# Enter a number: 1
# The factors of 1 are:
# 1
#  *
#  * *
#  * * *
#  * * * *

# %%
6
